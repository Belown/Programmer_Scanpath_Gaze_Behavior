# %%
import sys
import os

curr_dir = os.getcwd()
home_dir = os.path.dirname(curr_dir)
lib_dir = os.path.join(home_dir, 'EMIP-Toolkit')
sys.path.append(os.path.abspath(os.path.join(curr_dir, 'tools')))
sys.path.append(os.path.abspath(lib_dir))
os.chdir(lib_dir)

print(sys.path)

from emtk import parsers, visualization, util, aoi
# Out:
# ['E:\\Storage\\ETH\\7. Semester\\Thesis\\python\\python311.zip', 'E:\\Storage\\ETH\\7. Semester\\Thesis\\python\\DLLs', 'E:\\Storage\\ETH\\7. Semester\\Thesis\\python\\Lib', 'E:\\Storage\\ETH\\7. Semester\\Thesis\\python', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\.venv', '', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\.venv\\Lib\\site-packages', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\.venv\\Lib\\site-packages\\win32', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\.venv\\Lib\\site-packages\\win32\\lib', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\.venv\\Lib\\site-packages\\Pythonwin', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\Code\\Playground\\tools', 'e:\\Storage\\ETH\\7. Semester\\Thesis\\Code\\EMIP-Toolkit']

# %%
experiment_id = 'P131'
trial_id = '2'
sample_size = 3

# %%
eye_events, samples = parsers.McChesney(sample_size)
os.chdir(curr_dir)
# Out:
# e:\Storage\ETH\7. Semester\Thesis\Code\EMIP-Toolkit\emtk\parsers\McChesney.py:43: DtypeWarning: Columns (4,5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv(
# e:\Storage\ETH\7. Semester\Thesis\Code\EMIP-Toolkit\emtk\parsers\McChesney.py:43: DtypeWarning: Columns (4,5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv(
# e:\Storage\ETH\7. Semester\Thesis\Code\EMIP-Toolkit\emtk\parsers\McChesney.py:43: DtypeWarning: Columns (4,5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv(

# %%
from tools import image_generation
image_generation.mcchesney_gen(experiment_id = experiment_id, trial_id = trial_id, eye_events = eye_events, samples = samples, image_type = 'heatmap')
