# %%
from tools.auxiliary.metadata import metadata_query
from tools.auxiliarys import parse_corrected_emip_data





print(metadata_query(parse_corrected_emip_data()))
# Out:
# Processing data for 159 participants...
# ...
