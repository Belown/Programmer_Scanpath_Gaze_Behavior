# %%
# from tools.comparison import within_group_comparison
# from tools import auxiliary
# import pandas as pd

# # Example usage
# base_path = r"D:\Storage\ETH\Thesis\Code\query\output\expertise_experiment_language"
# eye_events_corrected = auxiliary.parse_corrected_emip_data()
# data_set = "corrected"

# comparison_results = within_group_comparison(base_path, eye_events_corrected, data_set)

# # Print or save results
# for group, comparisons in comparison_results.items():
#     print(f"Results for group: {group}")
#     for comparison in comparisons:
#         print(comparison)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取数据
data = pd.read_csv("comparison_results/high_results.csv")

# 选择一个分数类型（例如 Shape）
pivot_data = data.pivot("exp_a", "exp_b", "Shape")

# 绘制热力图
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_data, annot=True, cmap="coolwarm", fmt=".4f")
plt.title("Shape Score Heatmap")
plt.show()
# Out:
# C:\Users\Belown\AppData\Local\Temp\ipykernel_7300\582848988.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_data = data.pivot("exp_a", "exp_b", "Shape")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取数据
data = pd.read_csv("comparison_results/high_results.csv")

# 选择一个分数类型（例如 Shape）
pivot_data = data.pivot("exp_a", "exp_b", "Length")

# 绘制热力图
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_data, annot=True, cmap="coolwarm", fmt=".4f")
plt.title("Length Score Heatmap")
plt.show()
# Out:
# C:\Users\Belown\AppData\Local\Temp\ipykernel_7300\140689721.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_data = data.pivot("exp_a", "exp_b", "Length")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取数据
data = pd.read_csv("comparison_results/high_results.csv")

# 选择一个分数类型（例如 Shape）
pivot_data = data.pivot("exp_a", "exp_b", "Direction")

# 绘制热力图
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_data, annot=True, cmap="coolwarm", fmt=".4f")
plt.title("Direction Score Heatmap")
plt.show()
# Out:
# C:\Users\Belown\AppData\Local\Temp\ipykernel_7300\4154488646.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_data = data.pivot("exp_a", "exp_b", "Direction")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取数据
data = pd.read_csv("comparison_results/high_results.csv")

# 选择一个分数类型（例如 Shape）
pivot_data = data.pivot("exp_a", "exp_b", "Position")

# 绘制热力图
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_data, annot=True, cmap="coolwarm", fmt=".4f")
plt.title("Position Score Heatmap")
plt.show()
# Out:
# C:\Users\Belown\AppData\Local\Temp\ipykernel_7300\1055346539.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_data = data.pivot("exp_a", "exp_b", "Position")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取数据
data = pd.read_csv("comparison_results/high_results.csv")

# 选择一个分数类型（例如 Shape）
pivot_data = data.pivot("exp_a", "exp_b", "Duration")

# 绘制热力图
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_data, annot=True, cmap="coolwarm", fmt=".4f")
plt.title("Duration Score Heatmap")
plt.show()
# Out:
# C:\Users\Belown\AppData\Local\Temp\ipykernel_7300\2755581465.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_data = data.pivot("exp_a", "exp_b", "Duration")
