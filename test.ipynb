# %%
from tools.auxiliary.metadata import metadata_query
from tools.auxiliary import parse_corrected_emip_data

temp = metadata_query(parse_corrected_emip_data())
# Out:
# Processing data for 159 participants...
# Possible value for expertise_experiment_language are ['high', 'medium', 'none', 'low']
# Filtered experiment IDs saved to D:\Storage\ETH\Thesis\Code\query\output\expertise_experiment_language\low.csv
