# %%
import sys
import os
from emtk import parsers, visualization, util, aoi
from tools import setup_paths, image_generation

paths = setup_paths()
lib_path = paths["lib_path"]

# %%
experiment_id = 'P131'
trial_id = '2'
sample_size = 3

# %%
os.chdir(lib_path)
eye_events, samples = parsers.McChesney(sample_size)
# Out:
# D:\Storage\ETH\Thesis\Code\src\EMIP-Toolkit\emtk\parsers\McChesney.py:43: DtypeWarning: Columns (4,5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv(
# D:\Storage\ETH\Thesis\Code\src\EMIP-Toolkit\emtk\parsers\McChesney.py:43: DtypeWarning: Columns (4,5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv(
# D:\Storage\ETH\Thesis\Code\src\EMIP-Toolkit\emtk\parsers\McChesney.py:43: DtypeWarning: Columns (4,5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv(

# %%
image_generation.mcchesney_gen(experiment_id = experiment_id, trial_id = trial_id, eye_events = eye_events, samples = samples, image_type = 'heatmap')
