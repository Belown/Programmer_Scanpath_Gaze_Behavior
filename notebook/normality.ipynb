# %%
import pandas as pd
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data (replace with your filename)
df = pd.read_csv("D:\Storage\ETH\Thesis\Code\comparison_results\within_group\low_trial_id_5_results.csv")

# Define the five dimensions
dimensions = ["Shape", "Length", "Direction", "Position", "Duration"]

# Run Shapiro-Wilk test for each
print("Shapiro-Wilk normality test results:\n")
for dim in dimensions:
    stat, p = shapiro(df[dim])
    print(f"{dim:10s}  W = {stat:.4f},  p = {p:.4f}")
    if p > 0.05:
        print(" → Likely normal ✅\n")
    else:
        print(" → Not normal ❌\n")

# Optional: visualize distributions
for dim in dimensions:
    plt.figure(figsize=(6,4))
    sns.histplot(df[dim], kde=True)
    plt.title(f"{dim} distribution (within-group)")
    plt.show()
# Out:
# Shapiro-Wilk normality test results:
#
# Shape       W = 0.9600,  p = 0.0000
#  → Not normal ❌
#
# Length      W = 0.9836,  p = 0.0000
#  → Not normal ❌
#
# Direction   W = 0.9635,  p = 0.0000
#  → Not normal ❌
#
# Position    W = 0.9766,  p = 0.0000
#  → Not normal ❌
#
# Duration    W = 0.9549,  p = 0.0000
#  → Not normal ❌

# %%
from tools.statistics import normality_test
from tools.path import setup_paths
import os

paths = setup_paths()

data_dir = os.path.join(paths["home_path"], "comparison_results", "within_group")

normality_test(data_dir, if_graph=False)
# Out:
# Processing file: high_trial_id_2_results.csv
# Processing file: high_trial_id_5_results.csv
# Processing file: low_trial_id_2_results.csv
# Processing file: low_trial_id_5_results.csv
# Processing file: medium_trial_id_2_results.csv
# Processing file: medium_trial_id_5_results.csv
# Processing file: none_trial_id_2_results.csv
# Processing file: none_trial_id_5_results.csv
#
# Overall normality results based on majority:
# Shape      → Not normal ❌ (Normal: 0, Not normal: 8)
# Length     → Not normal ❌ (Normal: 3, Not normal: 5)
# Direction  → Not normal ❌ (Normal: 1, Not normal: 7)
# Position   → Not normal ❌ (Normal: 2, Not normal: 6)
# Duration   → Not normal ❌ (Normal: 3, Not normal: 5)
# {'Shape': {'normal': 0, 'not_normal': 8, 'result': 'Not normal'},
#  'Length': {'normal': 3, 'not_normal': 5, 'result': 'Not normal'},
#  'Direction': {'normal': 1, 'not_normal': 7, 'result': 'Not normal'},
#  'Position': {'normal': 2, 'not_normal': 6, 'result': 'Not normal'},
#  'Duration': {'normal': 3, 'not_normal': 5, 'result': 'Not normal'}}
