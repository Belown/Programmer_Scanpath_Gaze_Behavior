# %%
from emtk import parsers, visualization, util, aoi
from tools import setup_paths, image_generation
import os

paths = setup_paths()
lib_path = paths["lib_path"]

# %%
experiment_id = '001'
trial_id = '1'
sample_size = 8

# %%
os.chdir(lib_path)
eye_events, _ = parsers.AlMadi(sample_size)
# Out:
# Please cite this paper:  https://dl.acm.org/doi/10.1145/3448018.345742
# parsing file: 001.asc
# parsing file: 002.asc
# parsing file: 003.asc
# parsing file: 004.asc
# parsing file: 005.asc
# parsing file: 006.asc
# parsing file: 007.asc
# parsing file: 008.asc

# %%
image_generation.aimadi_gen(experiment_id=experiment_id, trial_id=trial_id, eye_events=eye_events)
